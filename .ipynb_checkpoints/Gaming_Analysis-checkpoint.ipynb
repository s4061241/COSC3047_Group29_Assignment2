# %%
# %pip install pyarrow pandas requests
# Out:
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.12/site-packages (16.1.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.16.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyarrow) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Check if reddit dataset exists locally

dataset_path = "data/reddit_gaming_madoc.parquet"

if not os.path.exists(dataset_path):
    raise FileNotFoundError(
        f"Please download the `reddit_gaming_madoc.parquet` dataset from Zenodo and place it at {dataset_path}\n"
        "See README for instructions."
    )

# %%
# Load your data
df = pd.read_parquet(dataset_path)

print("=" * 80)
print("MADOC DATASET - COMPLETE OVERVIEW")
print("=" * 80)

# ============================================================================
# 1. BASIC DATASET INFO
# ============================================================================
print("\n📊 DATASET SIZE:")
print(f"   Total rows: {len(df):,}")
print(f"   Total columns: {len(df.columns)}")
print(f"   Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

# ============================================================================
# 2. DATE RANGE (Critical for understanding your time window)
# ============================================================================
if 'publish_date' in df.columns:
    print("\n📅 DATE RANGE:")
    min_ts = df['publish_date'].min()
    max_ts = df['publish_date'].max()
    min_date = pd.to_datetime(min_ts, unit='s')
    max_date = pd.to_datetime(max_ts, unit='s')
    
    print(f"   From: {min_date} (Timestamp: {min_ts})")
    print(f"   To:   {max_date} (Timestamp: {max_ts})")
    print(f"   Duration: {(max_date - min_date).days} days")
    
    # Date distribution by year/month
    df['year'] = pd.to_datetime(df['publish_date'], unit='s').dt.year
    df['month'] = pd.to_datetime(df['publish_date'], unit='s').dt.month
    print(f"\n   Records by year:")
    year_counts = df['year'].value_counts().sort_index()
    for year, count in year_counts.items():
        print(f"     {year}: {count:,} ({count/len(df)*100:.1f}%)")

# ============================================================================
# 3. COMMUNITY ANALYSIS (For Reddit data)
# ============================================================================
if 'community' in df.columns:
    print("\n🏘️ COMMUNITY BREAKDOWN:")
    print(f"   Total unique communities: {df['community'].nunique():,}")
    
    # Top 20 communities
    print(f"\n   Top 20 communities by post/comment count:")
    top_communities = df['community'].value_counts().head(20)
    for idx, (community, count) in enumerate(top_communities.items(), 1):
        print(f"     {idx:2}. r/{community}: {count:10,} ({count/len(df)*100:.2f}%)")
    
    # Bottom communities (with very few posts)
    rare_communities = df['community'].value_counts()
    rare_count = (rare_communities <= 10).sum()
    print(f"\n   Communities with ≤10 interactions: {rare_count}")

# ============================================================================
# 4. INTERACTION TYPES (Posts vs Comments vs Reposts)
# ============================================================================
if 'interaction_type' in df.columns:
    print("\n💬 INTERACTION TYPES:")
    type_counts = df['interaction_type'].value_counts()
    for interaction_type, count in type_counts.items():
        print(f"   {interaction_type}: {count:10,} ({count/len(df)*100:.1f}%)")
    
    # For Reddit, understand post-to-comment ratio
    if 'POST' in type_counts.index and 'COMMENT' in type_counts.index:
        post_count = type_counts['POST']
        comment_count = type_counts['COMMENT']
        print(f"\n   Post-to-Comment Ratio: 1:{comment_count/post_count:.1f}")

# ============================================================================
# 5. USER ACTIVITY DISTRIBUTION
# ============================================================================
if 'user_id' in df.columns:
    print("\n👥 USER STATISTICS:")
    print(f"   Unique users: {df['user_id'].nunique():,}")
    
    # Posts per user distribution
    user_activity = df['user_id'].value_counts()
    print(f"   Avg interactions per user: {user_activity.mean():.2f}")
    print(f"   Median interactions per user: {user_activity.median():.2f}")
    print(f"   Max interactions by one user: {user_activity.max():,}")
    
    # Power users (top 1%)
    top_1_percent = int(len(user_activity) * 0.01)
    print(f"   Top 1% users produce: {user_activity.head(top_1_percent).sum():,} interactions ({user_activity.head(top_1_percent).sum()/len(df)*100:.1f}% of total)")

# ============================================================================
# 8. SAMPLE DATA SNIPPETS (Show what the dataset looks like)
# ============================================================================

# Show a few complete rows with key information
# Simple table view with just those columns
columns_to_show = ['post_id', 'publish_date', 'user_id', 'parent_id', 'parent_user_id', 
                   'community', 'interaction_type', 'content']

# Convert publish_date to readable format for display
df_display = df.copy()
if 'publish_date' in df_display.columns:
    df_display['publish_date'] = pd.to_datetime(df_display['publish_date'], unit='s')

# Show 20 random rows with those columns
pd.set_option('display.max_colwidth', 100)
print(df_display.sample(20)[columns_to_show])

# ============================================================================
# 9. DATA QUALITY CHECK
# ============================================================================
print("\n" + "=" * 80)
print("DATA QUALITY REPORT")
print("=" * 80)

print("\n⚠️ Missing values percentage:")
for col in df.columns:
    missing_pct = (df[col].isnull().sum() / len(df)) * 100
    if missing_pct > 0:
        print(f"   {col}: {missing_pct:.1f}%")

# Check for duplicates
if 'post_id' in df.columns:
    duplicates = df['post_id'].duplicated().sum()
    print(f"\n   Duplicate post_ids: {duplicates:,} ({duplicates/len(df)*100:.3f}%)")

# Check for data types issues
print(f"\n✅ Data types check:")
for col in df.columns:
    print(f"   {col}: {df[col].dtype}")
# Out:
# ================================================================================
# MADOC DATASET - COMPLETE OVERVIEW
# ================================================================================
#
# 📊 DATASET SIZE:
#    Total rows: 44,274,130
#    Total columns: 16
#    Memory usage: 32189.15 MB
#
# 📅 DATE RANGE:
#    From: 2014-01-01 00:00:04 (Timestamp: 1388534404)
#    To:   2020-12-31 23:59:57 (Timestamp: 1609459197)
#    Duration: 2556 days
#
#    Records by year:
#      2014: 4,842,491 (10.9%)
#      2015: 4,733,256 (10.7%)
#      2016: 4,961,830 (11.2%)
#      2017: 6,255,734 (14.1%)
#      2018: 8,184,988 (18.5%)
#      2019: 7,578,095 (17.1%)
#      2020: 7,717,736 (17.4%)
#
# 🏘️ COMMUNITY BREAKDOWN:
#    Total unique communities: 1
#
#    Top 20 communities by post/comment count:
#       1. r/gaming: 44,274,130 (100.00%)
#
#    Communities with ≤10 interactions: 0
#
# 💬 INTERACTION TYPES:
#    COMMENT: 41,386,090 (93.5%)
#    POST:  2,888,040 (6.5%)
#
#    Post-to-Comment Ratio: 1:14.3
#
# 👥 USER STATISTICS:
#    Unique users: 4,133,256
#    Avg interactions per user: 10.71
#    Median interactions per user: 2.00
#    Max interactions by one user: 40,063
#    Top 1% users produce: 14,778,900 interactions (33.4% of total)
#                                        post_id        publish_date  \
# 22723646  30f85506-e51e-50c7-93fc-cd5b6020b537 2018-04-11 21:29:54
# 846483    537e072a-0210-5a92-9168-1da36ab406a8 2014-02-19 11:26:47
# 14966617                                  None
# 2224691                                   None
# 43109372                                  None
# 32088226                                  None
# 25706257  9ca4a4ce-f028-5854-96f7-18f16d23c866
# 38963060                                  None
# 24426164                                  None
# 15042699                                  None
# 22180139                                  None
# 10296175                                  None
# 4519219                                   None
# 21258926  456270a8-4618-579e-bc22-5aa6c49e85bd
# 35311622                                  None
# 29219559                                  None
# 41090860                                  None
#
#                                 parent_user_id community interaction_type  \
# 22723646  6b027310-8da1-5779-b8a8-d5f0e4207fb5    gaming          COMMENT
# 846483                                    None    gaming          COMMENT
# 40534276                                  None    gaming             POST
# 10255209                                  None    gaming             POST
# 38549456  712d0c9a-95ad-5ff7-9577-1394e411b89f    gaming          COMMENT
# 14966617                                  None    gaming          COMMENT
# 2224691                                   None    gaming          COMMENT
# 43109372                                  None    gaming          COMMENT
# 32088226                                  None    gaming          COMMENT
# 25706257  2c0f2a66-5be5-567b-be98-f5eb7ed26f5a    gaming          COMMENT
# 38963060                                  None    gaming          COMMENT
# 24426164                                  None    gaming          COMMENT
# 15042699                                  None    gaming          COMMENT
# 22180139                                  None    gaming          COMMENT
# 10296175                                  None    gaming          COMMENT
# 4519219                                   None    gaming          COMMENT
# 21258926  f4167ac0-143d-5c2a-9018-291b2462254a    gaming          COMMENT
# 35311622                                  None    gaming          COMMENT
# 29219559                                  None    gaming          COMMENT
# 41090860                                  None    gaming          COMMENT
#
#                                                                                                       content
# 22723646                                                     I’m having problems w the nose... is it just me?
# 846483                                                                         Have you played Skyrim before?
# 40534276                                                                             What’s the best console?
# 10255209                                                       Is there a subreddit for sharing game reviews?
# 38549456                                                                                    Undertale for me.
# 14966617                                                            I get the feeling you work for Umbrella.
# 2224691   This is Glen Beck we are talking about.  He is so full of shit that the smell caused three death...
# 43109372                                                       OH boy you'd hate the StarCitizen_refunds sub.
# 32088226                                                                            We all have those moments
# 25706257                                                                                      Marry her. Now.
# 38963060                         Multiplayer coop? I see Destiny on their screens which is a great coop game.
# 24426164                         Thats a damn shame, for all gamers. Remind me in one year, and we will see.
# 15042699                                                                               Fuck that guy, though.
# 22180139                What's wrong with an EA game. I got it the day it came out and enjoyed it ever since.
# 10296175                                                                                         we shall see
# 4519219                                                                    does this work for nonsteam games?
# 21258926                                                 You forgot about girlfriends knitting and beads art.
# 35311622                                          Because it adds to the dumb of the tattoo. No other reason.
# 29219559                                                                                      Its so dreeeamy
# 41090860                      I absolutely loved MW but upgrades and tuning was very dumbed down from NFSU2..
#
# ================================================================================
# DATA QUALITY REPORT
# ================================================================================
#
# ⚠️ Missing values percentage:
#    parent_id: 65.9%
#    parent_user_id: 65.9%
#    url: 90.7%
#    strict_filter: 100.0%
#
#    Duplicate post_ids: 0 (0.000%)
#
# ✅ Data types check:
#    post_id: object
#    publish_date: int64
#    user_id: object
#    parent_id: object
#    parent_user_id: object
#    content: string
#    url: object
#    language: string
#    interaction_type: string
#    platform: object
#    community: object
#    strict_filter: object
#    sentiment_vader: float64
#    sentiment_textblob: float64
#    subjectivity_textblob: float64
#    toxicity_toxigen: float64
#    year: int32
#    month: int32

# %%
print(f"\nMissing content: {df['content'].isna().sum():,} rows")
# Out:
# Missing content: 0 rows
